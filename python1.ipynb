# %%
menorAltura = 0
maiorAltura = 0
contadorF = 0
somaAltF = 0
alturas = []
alturasM = []

for i in range(6):
    
    altura = float(input(f"{i+1} - Digite a altura: "))
    sexo = input(f"{1+i} - Digite o sexo (M/F):").upper()

    print(f"-------------------------------")
    
    if sexo == "F":
        contadorF += 1
        somaAltF += altura
    
    if(i == 0):
        menorAltura = altura
        maiorAltura = altura

    if altura < menorAltura:
        menorAltura = altura

    if altura > maiorAltura:
        maiorAltura = altura

print(f"-------------------------------")
print(f"A menor altura é: {menorAltura}")
print(f"A maior altura é: {maiorAltura}")
print(f"A média da altura das mulheres é: {somaAltF/contadorF:.2f}")
# Out:
# 1 - Digite a altura:  1.8
# 1 - Digite o sexo (M/F): f
# -------------------------------
# 2 - Digite a altura:  1.3
# 2 - Digite o sexo (M/F): f
# -------------------------------
# 3 - Digite a altura:  1.8
# 3 - Digite o sexo (M/F): f
# -------------------------------
# 4 - Digite a altura:  1.89
# 4 - Digite o sexo (M/F): f
# -------------------------------
# 5 - Digite a altura:  1.4
# 5 - Digite o sexo (M/F): f
# -------------------------------
# 6 - Digite a altura:  1.99
# 6 - Digite o sexo (M/F): m
# -------------------------------
# -------------------------------
# A menor altura é: 1.3
# A maior altura é: 1.99
# A média da altura das mulheres é: 1.64

# %% [markdown]
# alturas = []
# alturasM = []
#
# for i in range(6):
#     while True:
#         try:
#             altura = float(input(f"{i+1} - Digite a altura: "))
#             break
#         except ValueError:
#             print("
#     sexo = input(f"{1+i} - Digite o sexo (M/F):").upper()
#
#     print(f"-------------------------------")
#
#     if sexo == "F":
#         contadorF += 1
#         somaAltF += altura
#
#     if(i == 0):
#         menorAltura = altura
#         maiorAltura = altura
#
#     if altura < menorAltura:
#         menorAltura = altura
#
#     if altura > maiorAltura:
#         maiorAltura = altura
#
# print(f"-------------------------------")
# print(f"A menor altura é: {menorAltura}")
# print(f"A maior altura é: {maiorAltura}")
# print(f"A média da altura das mulheres é: {somaAltF/contadorF:.2f}")

# %%
alturas = []
alturasF = []

for i in range(3): 
    while True: 
        try: 
            altura = float(input(f"{i+1} - Digite a altura: ")) 
            break 
        except ValueError: 
            print("Digite uma valor válido")


    while True: 
        sexo = input(f"{1+i} - Digite o sexo (M/F):").upper() 
        if sexo in ['M','F']:
             break
        else:
            print("Digite um sexo válido")

    alturas.append(altura)
    print("-------------------------------")


    if sexo == "F":
        alturasF.append(altura)

print(f"-------------------------------") 
print(f"A menor altura é: {min(alturas)}")
print(f"A maior altura é: {max(alturas)}") 
print(f"A quantidade de mulheres é: {len(alturasF)}")
print(f"A média da altura das mulheres é: {sum(alturasF)/len(alturasF):.2f}")
# Out:
# 1 - Digite a altura:  1.2
# 1 - Digite o sexo (M/F): f
# -------------------------------
# 2 - Digite a altura:  1.7
# 2 - Digite o sexo (M/F): f
# -------------------------------
# 3 - Digite a altura:  1.4
# 3 - Digite o sexo (M/F): f
# -------------------------------
# -------------------------------
# A menor altura é: 1.2
# A maior altura é: 1.7
# A quantidade de mulheres é: 3
# A média da altura das mulheres é: 1.43
